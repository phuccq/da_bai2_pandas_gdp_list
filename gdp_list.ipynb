# %%
import pandas as pd
import numpy as np

data = pd.read_csv('GDPlist.csv',encoding='ISO-8859-1')
data.info()
display(data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                125 non-null    object
#  1   Continent              125 non-null    object
#  2   GDP (millions of US$)  125 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 3.1+ KB
#           Country      Continent  GDP (millions of US$)
# 0     Afghanistan           Asia                  18181
# 1         Albania         Europe                  12847
# 2         Algeria         Africa                 190709
# 3          Angola         Africa                 100948
# 4       Argentina  South America                 447644
# ..            ...            ...                    ...
# 120    Uzbekistan           Asia                  45353
# 121     Venezuela  South America                 315841
# ...

# %%
# Đổi tên cột
data.rename(columns={'Country':'Nuoc','Continent':'ChauLuc','GDP (millions of US$)':'GDP (trieu $)'},inplace=True)
display(data)
# Out:
#              Nuoc        ChauLuc  GDP (trieu $)
# 0     Afghanistan           Asia          18181
# 1         Albania         Europe          12847
# 2         Algeria         Africa         190709
# 3          Angola         Africa         100948
# 4       Argentina  South America         447644
# ..            ...            ...            ...
# 120    Uzbekistan           Asia          45353
# 121     Venezuela  South America         315841
# 122       Vietnam           Asia         122722
# 123         Yemen         Africa          33675
# 124        Zambia         Africa          19206
#
# [125 rows x 3 columns]

# %%
data.insert(1,'ThanhPho',data['Nuoc'])
display(data)
# Out:
#              Nuoc      ThanhPho        ChauLuc  GDP (trieu $)
# 0     Afghanistan   Afghanistan           Asia          18181
# 1         Albania       Albania         Europe          12847
# 2         Algeria       Algeria         Africa         190709
# 3          Angola        Angola         Africa         100948
# 4       Argentina     Argentina  South America         447644
# ..            ...           ...            ...            ...
# 120    Uzbekistan    Uzbekistan           Asia          45353
# 121     Venezuela     Venezuela  South America         315841
# 122       Vietnam       Vietnam           Asia         122722
# 123         Yemen         Yemen         Africa          33675
# 124        Zambia        Zambia         Africa          19206
#
# [125 rows x 4 columns]

# %%
data2 = pd.read_excel('country-capital.xlsx')

country=data2['Country']
capital=data2['Capital']
# print(country,capital)
change_value = {}
for i in range(0,data2.shape[0]):
#     print(data2.loc[i,'Country'],data2.loc[i,'Capital'])
    change_value[data2.loc[i,'Country']]=data2.loc[i,'Capital']
# print(change_value)

for country_value in change_value.keys():
    capital_value = change_value[country_value]
    column_changed=data['ThanhPho'].replace(country_value,capital_value,inplace=True,regex=True)

display(data)
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ...

# %%
drop_index_cont=data.loc[data.ChauLuc=="Asia"].index
data.drop(drop_index_cont,inplace=True)
display(data)
# Out:
#                Nuoc          ThanhPho        ChauLuc  GDP (trieu $)
# 1           Albania            Tirana         Europe          12847
# 2           Algeria           Algiers         Africa         190709
# 3            Angola            Luanda         Africa         100948
# 4         Argentina      Buenos Aires  South America         447644
# 5         Australia          Canberra        Oceania        1488221
# ..              ...               ...            ...            ...
# 118   United States   Washington D.C.  North America       15094025
# 119         Uruguay        Montevideo  South America          46872
# 121       Venezuela           Caracas  South America         315841
# 123           Yemen            Sana'a         Africa          33675
# 124          Zambia            Lusaka         Africa          19206
#
# [89 rows x 4 columns]

# %%
drop_index_gdp=data.loc[data['GDP (trieu $)']<300000].index
data.drop(drop_index_gdp,inplace=True)
display(data)
# Out:
#                 Nuoc                            ThanhPho        ChauLuc  \
# 4          Argentina                        Buenos Aires  South America
# 5          Australia                            Canberra        Oceania
# 6            Austria                              Vienna         Europe
# 11           Belgium                            Brussels         Europe
# 15            Brazil                            Brasilia  South America
# 21            Canada                              Ottawa  North America
# 24          Colombia                              Bogota  South America
# 32           Denmark                          Copenhagen         Europe
# 41            France                               Paris         Europe
# 44           Germany                              Berlin         Europe
# 46            Greece                              Athens         Europe
# 58             Italy                                Rome         Europe
# ...

# %%
data.loc[data['GDP (trieu $)']<300000]
# Out:
# Empty DataFrame
# Columns: [Nuoc, ThanhPho, ChauLuc, GDP (trieu $)]
# Index: []
